# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4), index = list('abcd'), columns = list('ABCD'))
data
# Out:
#     A   B   C   D
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %% [markdown]
# **1. 修改特定的row**

# %% [markdown]
# 1.1修改a的row

# %%
data.loc['a'] = ['A', 'B', 'C', 'D']
data

# %%
data.iloc[0] = ['A', 'B', 'C', 'E']
data
# Out:
#    A   B   C   D
# a  A   B   C   E
# b  B   5   6   7
# c  C   9  10  11
# d  D  13  14  15

# %% [markdown]
# **2. 修改特定的column**

# %% [markdown]
# 2.1修改A的column

# %%
data.loc[:,['A']] = ['A', 'B', 'C', 'D']
data
# Out:
#    A   B   C   D
# a  A   B   C   E
# b  B   5   6   7
# c  C   9  10  11
# d  D  13  14  15

# %%
data.iloc[:,[0]] = ['A', 'B', 'C', 'E']
data
# Out:
#    A   B   C   D
# a  A   B   C   E
# b  B   5   6   7
# c  C   9  10  11
# d  E  13  14  15

# %% [markdown]
# **3. 修改全部column**

# %%
data.columns = ['W', 'X', 'Y', 'Z']
data

# %% [markdown]
# **4. 插入特定row**

# %% [markdown]
# 4.1 插入到最後一row後面

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4), index = list('abcd'), columns = list('ABCD'))
dataAdd = pd.DataFrame(np.arange(4).reshape(1,4), index = list('e'), columns = list('ABCD'))
data = data.append(dataAdd)
data

# %% [markdown]
# 4.2 插入到指定row後面

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4), index = list('abcd'), columns = list('ABCD'))
dataAdd = pd.DataFrame(np.arange(4).reshape(1,4), index = list('e'), columns = list('ABCD'))
data1 = data.iloc[:1, :]
data2 = data.iloc[1:, :]
dataNew = pd.concat([data1, dataAdd, data2])
dataNew
# Out:
#     A   B   C   D
# a   0   1   2   3
# e   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %% [markdown]
# **5. 插入特定column**

# %% [markdown]
# 5.1 插入到最後一column之後

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4), index = list('abcd'), columns = list('ABCD'))
data['E'] = ['W', 'X', 'Y', 'Z']
data

# %% [markdown]
# 5.2 插入到指定row後面

# %%
dataRangeD = pd.date_range(start = '2021/09/01', end = '2021/9/30', freq = '1D') #freq = '1D': 間格是以1天為單位
dates = pd.DataFrame(dataRangeD, columns = ['Date'])
dates['Data'] = [1]*dates.shape[0]
dates.insert(1, "Day of Week", dates['Date'].dt.day_name())
dates
# Out:
#          Date Day of Week  Data
# 0  2021-09-01   Wednesday     1
# 1  2021-09-02    Thursday     1
# 2  2021-09-03      Friday     1
# 3  2021-09-04    Saturday     1
# 4  2021-09-05      Sunday     1
# 5  2021-09-06      Monday     1
# 6  2021-09-07     Tuesday     1
# 7  2021-09-08   Wednesday     1
# 8  2021-09-09    Thursday     1
# 9  2021-09-10      Friday     1
# 10 2021-09-11    Saturday     1
# 11 2021-09-12      Sunday     1
# 12 2021-09-13      Monday     1
# 13 2021-09-14     Tuesday     1
# 14 2021-09-15   Wednesday     1
# 15 2021-09-16    Thursday     1
# 16 2021-09-17      Friday     1
# 17 2021-09-18    Saturday     1
# 18 2021-09-19      Sunday     1
# 19 2021-09-20      Monday     1
# 20 2021-09-21     Tuesday     1
# 21 2021-09-22   Wednesday     1
# 22 2021-09-23    Thursday     1
# 23 2021-09-24      Friday     1
# 24 2021-09-25    Saturday     1
# 25 2021-09-26      Sunday     1
# 26 2021-09-27      Monday     1
# 27 2021-09-28     Tuesday     1
# 28 2021-09-29   Wednesday     1
# 29 2021-09-30    Thursday     1
